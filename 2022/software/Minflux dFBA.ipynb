# %%
import numpy as np
from scipy.integrate import odeint
# Libraries for the Metabolic block
import os
from os.path import join
data_dir="."
import matplotlib.pyplot as plt
import cobra
from cobra.io import read_sbml_model, write_sbml_model
model = cobra.io.read_sbml_model("iMM904.xml")


solution=model.optimize()
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_SC5_notrace = 0.28786570370401643</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>1.611</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.05691</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.02225</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-18.02</td>
#       <td>1</td>
#       <td>36.29%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_e</td>
#       <td>-15.82</td>
#       <td>2</td>
#       <td>63.70%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-0.001488</td>
#       <td>1</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-5.64</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-1.45</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
solution_fba = model.optimize()
print(solution_fba)

sumaFlujos = 0
for reaction in model.reactions:
    sumaFlujos += solution_fba[reaction.id]**2
print(model.objective.value, sumaFlujos)


model.reactions.BIOMASS_SC5_notrace.bounds=(solution_fba['BIOMASS_SC5_notrace'],solution_fba['BIOMASS_SC5_notrace'])

for i, reaction in enumerate(model.reactions):
    if i == 0:
        expresion_euclideana = model.reactions.get_by_id(reaction.id).flux_expression**2
    else:
        expresion_euclideana += model.reactions.get_by_id(reaction.id).flux_expression**2

objetivo_euclideano = model.problem.Objective(expresion_euclideana,direction="min")
model.objective = objetivo_euclideano
#print(objetivo_euclideano)
#Nueva distribución de flujo

solucion_minflux = model.optimize()

sumaFlujos = 0 
for reaction in model.reactions:
    sumaFlujos += solucion_minflux[reaction.id]**2
print(solucion_minflux['BIOMASS_SC5_notrace'], model.objective.value, sumaFlujos)
# Out:
# <Solution 0.488 at 0x7fd430664f50>
# 0.4881232305900678 12791.737357180187
# 0.4881232305900678 11918.834673707976 11918.83467370784

# %%
# Definición del bloque Cinético

def bloqueCinetico(Glu,Eth,Gly,Cit,Lac):
    # Parámetros
    vGmax, K_Glu, K_Eth = 22.5, 0.88, 6.74
    f_Eth,f_Gly, f_Cit, f_Lac = 0.112, 0.273, 0.169, 0.137
    v_Glu=(vGmax*Glu/(K_Glu+Glu))*(1/(1+Eth/K_Eth))
    LB_Eth = -v_Glu*f_Eth
    LB_Gly = -v_Glu*f_Gly
    LB_Cit = -v_Glu*f_Cit
    LB_Lac = -v_Glu*f_Lac
    return [v_Glu,LB_Eth,LB_Gly,LB_Cit,LB_Lac]


#Definición del bloque Metabólico

def bloqueMetabolico(v_Glu,LB_Eth,LB_Gly,LB_Cit,LB_Lac):
    model.reactions.get_by_id("EX_glc__D_e").bounds      = (-v_Glu,-v_Glu) # Define el flujo de glucosa
    model.reactions.get_by_id("EX_etoh_e").lower_bound   = LB_Eth
    model.reactions.get_by_id("EX_glyc_e").lower_bound   = LB_Gly
    model.reactions.get_by_id("EX_cit_e").lower_bound    = LB_Cit
    model.reactions.get_by_id("EX_lac__D_e").lower_bound = LB_Lac
    u = solution.objective_value
    v_Eth = model.reactions.get_by_id("EX_etoh_e").x
    v_Gly = model.reactions.get_by_id("EX_glyc_e").x
    v_Cit = model.reactions.get_by_id("EX_cit_e").x
    v_Lac = model.reactions.get_by_id("EX_lac__D_e").x
    return [u, v_Eth, v_Gly, v_Cit, v_Lac]


# Definición del Bloque Dinámico

def f(y,t,parametros):
    V,VX,VGlu,VEth,VGly,VCit,VLac = y #Current Values
    F, u, v_Glu, v_Eth, v_Gly, v_Cit, v_Lac = parametros #Unpack parameters
    # Tal que F=Flowrate(A,B,C,S,Y,V,X,t)
    Glu_F = 300
    MW_Glu,MW_Eth,MW_Gly,MW_Cit,MW_Lac = [0.18,.046,.092,.192,.090]
    
    derivadas = [F,                        #dV/dt
                 u*VX,                     #dVX/dt
                 F*Glu_F-v_Glu*MW_Glu*(VX),#VGlu/dt
                 v_Eth*MW_Eth*(VX),        #dVEth/dt
                 v_Gly*MW_Gly*(VX),        #dVGly/dt
                 v_Cit*MW_Cit*(VX),        #dVCit/dt
                 v_Lac*MW_Lac*(VX)]        #dVLac/dt
    return derivadas


def bloqueDinamico(y,parametros,ti,tf):
    time = np.linspace(ti,tf,200)
    #F, u, v_Glu, v_Eth, v_Gly, v_Cit, v_Lac = parametros
    solcn = odeint(f,y,time,args=(parametros))
    #Obtención de la solución en el último tiempo (tf)
    V = solcn[-1,0]
    X,Glu,Eth,Gly,Cit,Lac=soln[-1,1:7]/V
    return [V,X,Glu,Eth,Gly,Cit,Lac]


# Guardado de resultados durante la trayectoria de la fermentación
u_path,V_path,X_path = [],[],[]
Glu_path,Eth_path,Gly_path,Cit_path,Lac_path = [],[],[],[],[]
v_Glu_path=[]

def savepath(u,V,X,Glu,Eth,Gly,Cit,Lac,v_Glu):
    global u_path,V_path,X_path # Se declaran variables globales
    global Glu_path,Eth_path,Gly_path,Cit_path,Lac_path
    global v_Glu_path
    u_path += [u]
    V_path += [V]
    X_path += [X]
    Glu_path += [Glu]
    Eth_path += [Eth]
    Gly_path += [Gly]
    Cit_path += [Cit]
    Lac_path += [Lac]
    v_Glu_path += [v_Glu]

# %%
### Implementación del Ciclo Iterativo
##
# Condiciones Iniciales
Glu = 30
Eth,Gly,Cit,Lac = [3,0.75,0.1,0.2]
V,X = [0.5,1]
F = 0.25

#Definición de la simulación en el tiempo
time = np.linspace(0,20,200)

for i in range(len(time)):#El ciclo recorre el tiempo definido(20h,200x)
    # 1ro Para el bloque cinético:
    # Dadas las condiciones de glucosa y etanol,
    # Se calculan los flujos de glucosa y los límites superiores e inferiores de los demás metabolitos
    v_Glu,LB_Eth,LB_Gly,LB_Cit,LB_Lac = bloqueCinetico(Glu,Eth,Gly,Cit,Lac)
    # 2do Para el bloque metabólico:
    # Dados los valores de v_Glu,LB_Eth,LB_Gly,LB_Cit,LB_Lac
    # Se calcula la tasa de crecimiento de biomasa (u) y los flujos metabólicos de los metabolitos
    u, v_Eth, v_Gly, v_Cit, v_Lac = bloqueMetabolico(v_Glu,LB_Eth,LB_Gly,LB_Cit,LB_Lac)
    # 3ro Para el bloque dinámico:
    # Dados los valores de u, V, los flujos de (v_Eth, v_Gly, v_Cit, v_Lac)
    # y las concentraciones de (X,Glu,Eth,Gly,Cit,Lac)
    # Actualizamos el volumen de la reacción V, X y Glu,Eth,Gly,Cit,Lac
    if i == len(time)-1: continue 
    y = [V,X*V,Glu*V,Eth*V,Gly*V,Cit*V,Lac*V]
    parametros = [F(time[i]),u,v_Glu, v_Eth, v_Gly, v_Cit, v_Lac]
    V,X,Glu,Eth,Gly,Cit,Lac = bloqueDinamico(y, parametros, time[i],time[i+1])
    # Guardamos los resultados de las trayectorias a lo largo de la fermentación
    savepath(u,V,X,Glu,Eth,Gly,Cit,Lac,v_Glu)
# Out:
# ---------------------------------------------------------------------------
# CplexSolverError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/optlang/cplex_interface.py in _get_primal(self)
#     189         try:
# --> 190             return self.problem.problem.solution.get_values(self.name)
#     191         except CplexSolverError as err:
#
# /usr/local/lib/python3.7/dist-packages/cplex/_internal/_subinterfaces.py in get_values(self, *args)
#    7245         return apply_freeform_two_args(
# -> 7246             getx, self._cplex.variables._conv, args)
#    7247
#
# /usr/local/lib/python3.7/dist-packages/cplex/_internal/_aux_functions.py in apply_freeform_two_args(fn, conv, args, unpack_single)
#     148         if isinstance(conarg0, int):
# --> 149             result = fn(conarg0, conarg0)
#     150             if unpack_single:
#
# /usr/local/lib/python3.7/dist-packages/cplex/_internal/_subinterfaces.py in getx(a, b)
#    7243         def getx(a, b=self._cplex.variables.get_num() - 1):
# -> 7244             return CPX_PROC.getx(self._env._e, self._cplex._lp, a, b)
#    7245         return apply_freeform_two_args(
#
# /usr/local/lib/python3.7/dist-packages/cplex/_internal/_procedural.py in getx(env, lp, begin, end)
#    1998     status = CR.CPXXgetx(env, lp, x, begin, end)
# -> 1999     check_status(env, status)
#    2000     return LAU.array_to_list(x, xlen)
#
# /usr/local/lib/python3.7/dist-packages/cplex/_internal/_procedural.py in __call__(self, env, status, from_cb)
#     248                     error_string = geterrorstring(env, status)
# --> 249             raise CplexSolverError(error_string, env, status)
#     250
#
# CplexSolverError: CPLEX Error  1217: No solution exists.
#
# During handling of the above exception, another exception occurred:
#
# SolverError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/cobra/core/reaction.py in flux(self)
#     332             check_solver_status(self._model.solver.status)
# --> 333             return self.forward_variable.primal - self.reverse_variable.primal
#     334         except AttributeError:
#
# /usr/local/lib/python3.7/dist-packages/optlang/interface.py in primal(self)
#     279         if self.problem:
# --> 280             return self._get_primal()
#     281         else:
#
# /usr/local/lib/python3.7/dist-packages/optlang/cplex_interface.py in _get_primal(self)
#     191         except CplexSolverError as err:
# --> 192             raise SolverError(str(err))
#     193
#
# SolverError: CPLEX Error  1217: No solution exists.
#
# The above exception was the direct cause of the following exception:
#
# OptimizationError                         Traceback (most recent call last)
# /tmp/ipykernel_53374/4216410054.py in <module>
#      18     # Dados los valores de v_Glu,LB_Eth,LB_Gly,LB_Cit,LB_Lac
#      19     # Se calcula la tasa de crecimiento de biomasa (u) y los flujos metabólicos de los metabolitos
# ---> 20     u, v_Eth, v_Gly, v_Cit, v_Lac = bloqueMetabolico(v_Glu,LB_Eth,LB_Gly,LB_Cit,LB_Lac)
#      21     # 3ro Para el bloque dinámico:
#      22     # Dados los valores de u, V, los flujos de (v_Eth, v_Gly, v_Cit, v_Lac)
#
# /tmp/ipykernel_53374/3749826052.py in bloqueMetabolico(v_Glu, LB_Eth, LB_Gly, LB_Cit, LB_Lac)
#      22     model.reactions.get_by_id("EX_lac__D_e").lower_bound = LB_Lac
#      23     u = solution.objective_value
# ---> 24     v_Eth = model.reactions.get_by_id("EX_etoh_e").x
#      25     v_Gly = model.reactions.get_by_id("EX_glyc_e").x
#      26     v_Cit = model.reactions.get_by_id("EX_cit_e").x
#
# /usr/local/lib/python3.7/dist-packages/cobra/core/reaction.py in x(self)
#     510         """
#     511         warn("Please use reaction.flux instead.", DeprecationWarning)
# --> 512         return self.flux
#     513
#     514     @property
#
# /usr/local/lib/python3.7/dist-packages/cobra/core/reaction.py in flux(self)
#     344                     "".format(str(err))
#     345                 ),
# --> 346                 err,
#     347             )
#     348
#
# /usr/local/lib/python3.7/dist-packages/future/utils/__init__.py in raise_from(exc, cause)
#     401         myglobals['__python_future_raise_from_cause'] = cause
#     402         execstr = "raise __python_future_raise_from_exc from __python_future_raise_from_cause"
# --> 403         exec(execstr, myglobals, mylocals)
#     404
#     405     def raise_(tp, value=None, tb=None):
#
# /usr/local/lib/python3.7/dist-packages/cobra/core/reaction.py in <module>
#
# OptimizationError: Likely no solution exists. Original solver message: CPLEX Error  1217: No solution exists..
